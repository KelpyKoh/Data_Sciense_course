# %%
import pandas  as pd

# %%
ratings_movies = pd.read_csv('/home/julia/IDE/учеба Skillfactory/PY-12_ Продвинутые методы работы с данными в Pandas/data/ratings_movies.csv')
ratings_movies.head()
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
#вставим функцию, которая будет получать год выпуска фильмов из описания по шаблону (DDDD)
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)
ratings_movies.head(10)
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
# 5           5       1       70     3.0  2000-07-30 18:40:00
# 6           6       1      101     5.0  2000-07-30 18:14:28
# 7           7       1      110     4.0  2000-07-30 18:36:16
# 8           8       1      151     5.0  2000-07-30 19:07:21
# 9           9       1      157     5.0  2000-07-30 19:08:20
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# ...

# %%
ratings_movies.describe().loc[:, 'year_release']
# Out:
# count    100818.000000
# mean       1994.444990
# std          14.361424
# min        1902.000000
# 25%        1990.000000
# 50%        1997.000000
# 75%        2003.000000
# max        2018.000000
# Name: year_release, dtype: float64

# %%
mask_year = ratings_movies['year_release'] == 1999
masked_movies = ratings_movies[mask_year]

masked_movies.groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
mask_year2 = ratings_movies['year_release'] == 2010
masked_movies2 = ratings_movies[mask_year2]

masked_movies2.groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
ratings_movies.groupby('userId')['rating'].agg(['count', 'mean']).sort_values(by=['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mask_2018 = ratings_movies['year_release'] == 2018
ratings_2018 = ratings_movies[mask_2018]
ratings_2018.groupby('genres')['rating'].agg(['count', 'mean']).sort_values(by=['count', 'mean'], ascending=[False, False])
# Out:
#                                         count      mean
# genres
# Action|Adventure|Sci-Fi                    14  3.928571
# Action|Comedy|Sci-Fi                       12  3.875000
# Comedy                                      8  3.312500
# Action|Adventure|Children|Sci-Fi            5  3.900000
# Animation|Comedy                            5  3.500000
# Action|Adventure|Animation|Children         4  3.000000
# Drama|Horror|Thriller                       4  2.750000
# Action|Adventure|Fantasy                    4  2.500000
# Adventure|Mystery|Sci-Fi|Thriller           3  3.833333
# Action|Adventure|Comedy|Fantasy|Sci-Fi      3  3.666667
# Documentary                                 2  4.000000
# Action|Adventure|Thriller                   2  3.750000
# Action|Adventure|Drama|Sci-Fi|Thriller      2  3.250000
# Comedy|Drama                                2  3.250000
# Action|Fantasy|Sci-Fi                       2  2.750000
# Horror|Mystery|Sci-Fi|Thriller              2  2.250000
# ...

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'])

# %%
ratings_movies['year_rating'] = ratings_movies['date'].dt.year
ratings_movies.tail(10)
# Out:
#         Unnamed: 0  userId  movieId  rating                date  \
# 100826      100826     610   162350     3.5 2017-05-03 22:19:31
# 100827      100827     610   163937     3.5 2017-05-03 21:59:49
# 100828      100828     610   163981     3.5 2017-05-03 22:22:35
# 100829      100829     610   164179     5.0 2017-05-03 21:07:11
# 100830      100830     610   166528     4.0 2017-05-04 06:29:25
# 100831      100831     610   166534     4.0 2017-05-03 21:53:22
# 100832      100832     610   168248     5.0 2017-05-03 22:21:31
# 100833      100833     610   168250     5.0 2017-05-08 19:50:47
# 100834      100834     610   168252     5.0 2017-05-03 21:19:12
# 100835      100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                       title                           genres  \
# 100826         The Magnificent Seven (2016)                   Action|Western
# 100827                   Blair Witch (2016)                  Horror|Thriller
# ...

# %%
pivot_ratings = ratings_movies.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres'
)
pivot_ratings['Action|Adventure'].min()
# Out:
# 3.2777777777777777

# %%
pivot_ratings['Action|Adventure|Animation|Children|Comedy|IMAX'].sort_values()
# Out:
# year_rating
# 2017    1.000000
# 2009    3.250000
# 2015    3.375000
# 2010    3.500000
# 2014    3.500000
# 2012    3.550000
# 2016    3.666667
# 2018    3.700000
# 2013    5.000000
# 1996         NaN
# 1997         NaN
# 1998         NaN
# 1999         NaN
# 2000         NaN
# 2001         NaN
# 2002         NaN
# 2003         NaN
# 2004         NaN
# 2005         NaN
# 2006         NaN
# 2007         NaN
# 2008         NaN
# 2011         NaN
# Name: Action|Adventure|Animation|Children|Comedy|IMAX, dtype: float64

# %%
pivot_ratings.loc[2018, :].sort_values(ascending=False).head(15)
# Out:
# genres
# Animation|Comedy|Drama                       5.0
# Crime|Mystery                                5.0
# Comedy|Crime|Fantasy                         5.0
# Crime|Fantasy|Horror                         5.0
# Comedy|Crime|Horror|Thriller                 5.0
# Animation|Crime|Drama                        5.0
# Drama|Romance|War                            5.0
# Action|Comedy|Documentary                    5.0
# Animation|Comedy|Fantasy|Musical             5.0
# Animation|Comedy|Drama|Fantasy|Sci-Fi        5.0
# Comedy|Drama|Fantasy|Mystery|Romance         5.0
# Animation|Children|Mystery                   5.0
# Drama|Horror|Mystery|Sci-Fi|Thriller         5.0
# Adventure|Children|Comedy|Fantasy|Mystery    5.0
# Comedy|Fantasy|Horror|Musical|Thriller       5.0
# Name: 2018, dtype: float64

# %%
pivot_ratings['Comedy']
# Out:
# year_rating
# 1996    3.228571
# 1997    3.409091
# 1998    3.000000
# 1999    3.606061
# 2000    3.141291
# 2001    3.318408
# 2002    3.198556
# 2003    3.120066
# 2004    3.356877
# 2005    2.963325
# 2006    3.347534
# 2007    2.928187
# 2008    3.426667
# 2009    3.273292
# 2010    3.179825
# 2011    3.232877
# 2012    3.478477
# 2013    3.489474
# 2014    3.271429
# 2015    3.106183
# 2016    3.373431
# 2017    2.852668
# 2018    3.121296
# Name: Comedy, dtype: float64

# %%
import pandas as pd
orders = pd.read_csv('/home/julia/IDE/учеба Skillfactory/PY-12_ Продвинутые методы работы с данными в Pandas/data/orders_and_products/orders.csv', sep=';')
orders.head()
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество
# 0     Нет     Нет      Нет        103           5
# 1     Нет     Нет      Нет         86         100
# 2     Нет     Нет      Нет        104          10
# 3     Нет     Нет      Нет        104           7
# 4     Нет     Нет      Нет        104           5

# %%
products = pd.read_csv('/home/julia/IDE/учеба Skillfactory/PY-12_ Продвинутые методы работы с данными в Pandas/data/orders_and_products/products.csv', sep=';')
products.head()
# Out:
#    Product_ID                      Name  Price CURRENCY
# 0          47      Шатны Полосатый рейс   2999      RUR
# 1          51  Платье Аленький цветочек   4999      RUR
# 2          53    Штаны Цветочная Поляна   4999      RUR
# 3          71       Платье Ночная Жизнь   7999      RUR
# 4          74  Платье Ночная Жизнь XXXL   8999      RUR

# %%
orders_products = orders.merge(
    products,
    left_on='ID товара',
    right_on='Product_ID',
    how='left'
)

display(orders_products)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_payed = orders_products[orders_products['Оплачен']=='Да']

orders_payed['total'] = orders_payed['Количество'] * orders_payed['Price']
orders_payed
#orders_products.groupby('ID Покупателя')[]
# Out:
# /tmp/ipykernel_61411/4218441225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_payed['total'] = orders_payed['Количество'] * orders_payed['Price']
#           Дата создания  Order ID  ID Покупателя  \
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_payed.groupby('ID Покупателя')['total'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: total, dtype: float64
